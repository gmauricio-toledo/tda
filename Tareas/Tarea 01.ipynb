# %% [markdown]
# <a href="https://colab.research.google.com/github/gmauricio-toledo/tda/blob/main/Tareas/Tarea%2001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Tarea 1</h1>

# %% [markdown]
# # Parte 1

# %% [markdown]
# Se proporcionan varios conjuntos de datos. Cada uno consiste en puntos muestreados de una variedad desconocida, originalmente en dimensión baja pero encajada en $\mathbb{R}^D$ con $D$ grande.
#
# **Objetivo:** Usando únicamente herramientas básicas de NumPy, matplotlib y estadística descriptiva, caracterizar cada conjunto de datos y formular una hipótesis sobre la geometría de la variedad subyacente.
#
# * GARCIA BARRAZA SANDRA GABRIELA: `!gdown 1D4r4XzmHAaApzuDBcof9eybMW_zF2Wm2`
# * HUERTA VALDEZ LUIS CARLOS: `!gdown 1H8KjJ6m_xXk2qCGW7elZCSFwaDaZss4o`
# * MOLINA ORTIZ JESUS EMMANUEL: `!gdown 1KHIHzT2Z-wykes3LLIp2Idl71Hw2LWtP`
# * MONDRAGON PEREZ JORGE MAURICIO: `!gdown 1XBrcDKsvUI757vwPklrYuHCeMXXdnLXt`
# * NAVARRO MENDIVIL JORGE PABLO: `!gdown 1gfuq5N8pfEJVhMz7MEH9owWpz7tmPRR0`
# * ROJAS ALCANTAR JESUS ANGEL: `!gdown 1oGoUVjnGQHIld7jLgjqN6Rjtg3DG87ft`

# %% [markdown]
# 🔴 Descarga el conjunto de datos

# %%
# !gdown ...

# %% [markdown]
# 🟢 Leer el archivo

# %%
import numpy as np

nombre_archivo = ""
X = np.loadtxt(nombre_archivo)

# %% [markdown]
# 🔴 Encuentra el tamaño del conjunto de datos, ¿cuántos puntos son? ¿en qué espacio viven?

# %% [markdown]
# 🔴 Encuentra el centroide de los datos

# %% [markdown]
# 🔴 Haz una traslación adecuada, si lo consideras necesario

# %% [markdown]
# 🔴 Realiza al menos 3 proyecciones en $\mathbb{R}^2$ y grafícalas con `plt.scatter`

# %%
import matplotlib.pyplot as plt

normas = np.linalg.norm(X,axis=1)

plt.figure()
plt.hist(normas)
plt.show()

# %% [markdown]
# 🔴Explorar libremente el conjunto de datos. Algunas técnicas que pueden considerar:
#
# * Máximos, mínimos, promedios y varianzas de coordenadas
# * Análisis de distancias: desde el origen, desde el centroide, desde un punto arbitrario
# * Proyecciones: visualizar en pares o ternas de coordenadas
# * Distribuciones: histogramas de cantidades relevantes

# %% [markdown]
# 🔴 Formula una hipótesis de qué variedad, o espacio topológico, vienen tus datos

# %% [markdown]
# # Parte 2

# %% [markdown]
# 1. Sea $A\subset \mathbb{R}^D$ con $|A|=N$ y $N < D$, encuentra $F:\mathbb{R}^D\rightarrow \mathbb{R}^N$ tal que $F$ es una isometría en $A$.
#
#     *Hint*: Traslada los puntos de forma que algún punto de $A$ quede en el origen y proyecta a un subespacio vectorial apropiado.
#
# 2. Demuestra que si $H\in \mathcal{M}_{n\times n}(\mathbb{C})$ es una matriz Hermitiana entonces todos los eigenvalores de $H$ son reales.
