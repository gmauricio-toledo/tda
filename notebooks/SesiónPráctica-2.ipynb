# %% [markdown]
# <a href="https://colab.research.google.com/github/gmauricio-toledo/tda/blob/main/notebooks/Sesi%C3%B3nPr%C3%A1ctica-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(f"Train shape: {x_train.shape}")
print(f"Train labels shape: {y_train.shape}")
print(f"Test shape: {x_test.shape}")
print(f"Test labels shape: {y_test.shape}")
# Out:
# Train shape: (60000, 28, 28)
# Train labels shape: (60000,)
# Test shape: (10000, 28, 28)
# Test labels shape: (10000,)

# %%
fname = ...
idxs = np.loadtxt(fname, dtype=int)

# Construir dataset
X_session = x_train[idxs]  # shape (n, 28, 28)
y_session = y_train[idxs]

print(f"Estudiante {STUDENT_ID}, Sesión {SESSION_ID}")
print(f"X shape: {X_session.shape}")
print(f"y shape: {y_session.shape}")

# Verificar balance de clases
for k in range(10):
    print(f"  Dígito {k}: {np.sum(y_session == k)} ejemplos")
# Out:
# Estudiante 1, Sesión 1
# X shape: (200, 28, 28)
# y shape: (200,)
#   Dígito 0: 20 ejemplos
#   Dígito 1: 20 ejemplos
#   Dígito 2: 20 ejemplos
#   Dígito 3: 20 ejemplos
#   Dígito 4: 20 ejemplos
#   Dígito 5: 20 ejemplos
#   Dígito 6: 20 ejemplos
#   Dígito 7: 20 ejemplos
#   Dígito 8: 20 ejemplos
#   Dígito 9: 20 ejemplos
