# %% [markdown]
# <a href="https://colab.research.google.com/github/gmauricio-toledo/tda/blob/main/notebooks/Sesi%C3%B3nPr%C3%A1ctica-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Parte 1: Lunes 6 de abril

# %%
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(f"Train shape: {x_train.shape}")
print(f"Train labels shape: {y_train.shape}")
print(f"Test shape: {x_test.shape}")
print(f"Test labels shape: {y_test.shape}")

# %%
fname = ...
idxs = np.loadtxt(fname, dtype=int)

# Construir dataset
X_session = x_train[idxs]  # shape (n, 28, 28)
y_session = y_train[idxs]

print(f"X shape: {X_session.shape}")
print(f"y shape: {y_session.shape}")

# %% [markdown]
# # Parte 2: Martes 7 de abril

# %%
# !gdown --folder 1LUFGnCKDFcRJriwU-PgM8a-MxiCcBWJU

# %% [markdown]
# Escoger un método de representación vectorial para los diagramas de persistencia:
#
# * [Landscapes](https://giotto-ai.github.io/gtda-docs/latest/modules/generated/diagrams/representations/gtda.diagrams.PersistenceLandscape.html#persistencelandscape)
# * [Curvas de Betti](https://giotto-ai.github.io/gtda-docs/latest/modules/generated/diagrams/representations/gtda.diagrams.BettiCurve.html#betticurve)
# * [Imágenes](https://giotto-ai.github.io/gtda-docs/latest/modules/generated/diagrams/representations/gtda.diagrams.PersistenceImage.html)
#
# Aplicar dicho método a todos los 12 archivos que generaron ayer

# %%
# !pip install giotto-tda

# %%
import numpy as np
import os
from gtda.diagrams import ...  # Importar el método de representación escogido

path = '/content/TDA-MNIST-diagramas'

#--- Folder donde guardamos los resultados ---
output_path = '/content/TDA-MNIST-features'
os.makedirs(output_path, exist_ok=True)
#-----------------------------------------

for root, dirs, files in os.walk(path):
    for file in files:
        if file.endswith('.npy'): # and 'pablo' not in file:
            X = np.load(os.path.join(root, file), allow_pickle=True) # Leer el diagrama de persistencia
            #---- aplicar el método de representación que vayas a usar
            ...
            X_features = ...
            #---- guardar el arreglo X_features con np.save como [nombre original]_[metodo de representacion].npy
            metodo_rep = ... # Pon entre comillas la abreviación del metodo de representación, por ejemplo, Landscapes: metodo_rep = 'landsc'
            fname = file.split('.')[0] + metodo_rep + '.npy'
            np.save(os.path.join(output_path, fname), X_features)

# %% [markdown]
# No olviden, bajar el contenido de la carpeta y subir los archivos a la subcarpeta correspondiente de
#
# https://drive.google.com/drive/folders/1-SY9Ci5hvCCkHXU14DRTlefBvIh3FZMx?usp=sharing

# %% [markdown]
# # Parte 3: Miércoles 8 de abril

# %% [markdown]
# Instrucciones:
#
# 1. Descargar tu carpeta con las representaciones vectoriales de los diagramas de persistencia del dataset MNIST
# 2. Ponlas en una sola carpeta
# 3. Adapta el código de la celda anterior para que leas cada archivo npy y los concatenes todos los arreglos en uno solo usando `np.concatenate`

# %%
X = None

path = ...

for root, dirs, files in os.walk(path):
    for file in files:
        if file.endswith('.npy'):
            arr = np.load...
            if X is None:
                X = arr
            else:
                X = np.concatenate([X, arr], axis=0)

print(X.shape)

# %% [markdown]
# 4. Aplana con `reshape` para que cada diagrama esté representado por un sólo vector

# %%
X = X.reshape(len(X), -1)

# %% [markdown]
# 5. Estima el accuracy de una tarea de clasificación con `sklearn.model_selection.cross_validate`

# %% [markdown]
# # Parte 4: Jueves 9 de abril

# %%
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(f"Train shape: {x_train.shape}")
print(f"Train labels shape: {y_train.shape}")
print(f"Test shape: {x_test.shape}")
print(f"Test labels shape: {y_test.shape}")

# %% [markdown]
# Obtener el diagrama de persistencia con el complejo cubical de todos los elementos de `x_train` y `x_test` por separado

# %% [markdown]
# Escoger un método de representación vectorial para los diagramas de persistencia:
#
# * [Landscapes](https://giotto-ai.github.io/gtda-docs/latest/modules/generated/diagrams/representations/gtda.diagrams.PersistenceLandscape.html#persistencelandscape)
# * [Curvas de Betti](https://giotto-ai.github.io/gtda-docs/latest/modules/generated/diagrams/representations/gtda.diagrams.BettiCurve.html#betticurve)
# * [Imágenes](https://giotto-ai.github.io/gtda-docs/latest/modules/generated/diagrams/representations/gtda.diagrams.PersistenceImage.html)
#
# Aplicar dicho método a los 2 conjuntos de diagramas del paso anterior

# %% [markdown]
# Aplana con `reshape` para que cada diagrama esté representado por un sólo vector, ejemplo:
#
#         X = X.reshape(len(X), -1)

# %% [markdown]
# Escoge un clasificador:
#
# * [KNeighborsClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html)
# * [SVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html)
# * [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)
# * [RandomForestClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)
# * [LogisticRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html)
# * [AdaBoostClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html)
# * [GaussianNB](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html)
# * [MLPClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html)
#
# y hacer la clasificación, ejemplo:

# %%
from sklearn.metrics import accuracy_score

modelo = ...
modelo.fit(X_train_features, y_train)  # entrenamiento del clasificador

y_train_pred = modelo.predict(X_train_features)  # generar predicciones del conjunto de entrenamiento
y_test_pred = modelo.predict(X_test_features)    # generar predicciones del conjunto de prueba

train_acc = accuracy_score(y_train, y_train_pred) # Calcular accuracy para entrenamiento
test_acc = accuracy_score(y_test, y_test_pred)    # Calcular accuracy para prueba

print(f"Train accuracy: {train_acc}")
print(f"Test accuracy: {test_acc}")

# %% [markdown]
# **Modifica hiperparámetros para intentar obtener mejor accuracy**

# %% [markdown]
# Veamos la matriz de confusión entre predicciones y valores reales

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_test_pred)

plt.figure(figsize=(10,10))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion matrix')
plt.xticks(range(10))
plt.yticks(range(10))
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.colorbar()
plt.show()

# %% [markdown]
# Prueba a hacer predicciones con 3 dígitos escritos por tí:
#
# * Escribe un dígito en una hoja (básate en la matriz de confusión)
# * Tómale foto
# * Guardalo como imagen png
# * Súbela a colab
# * Ejecuta la celda siguiente con las modificaciones pertinentes

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

def procesar_imagen(ruta_imagen):
    '''
    Función para convertir una imagen a un arreglo de numpy de 28x28 en escala de grises
    '''
    img = Image.open(ruta_imagen) # Leer la imagen
    img_gris = img.convert('L') # Convertir a escala de grises
    img_28x28 = img_gris.resize((28, 28),
                                # Image.Resampling.LANCZOS
                                ) # Redimensionar a 28x28 píxeles
    arreglo = np.array(img_28x28, dtype=int) # Convertir a arreglo NumPy
    arreglo = np.clip(arreglo, 0, 255) # Asegurar que los valores están en 0-255
    return arreglo


ruta = ... # Cambia por tu ruta

arreglo_28x28 = procesar_imagen(ruta)
arreglo_28x28 = 255 - arreglo_28x28  # Invierte colores
# arreglo_28x28 = arreglo_28x28.astype('int')/255

plt.figure(figsize=(4,4))
plt.imshow(arreglo_28x28, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# Apliquemos todo el pipeline a esta imagen

# %%
diag = cp.transform([...])
landscape = ...
landscape = landscape.reshape(landscape.shape[0], -1)

prediccion = modelo.predict(...)
print(f"Predicción: {prediccion[0]}")
